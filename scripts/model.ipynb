# %% [markdown]
# ## 1. Load the packages

# %%
# Data processing packages
import numpy as np
import pandas as pd
from collections import Counter

# Machine learning packages
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MultiLabelBinarizer, FunctionTransformer
from sklearn.pipeline import Pipeline
import torch

# Visualization packages
import seaborn as sns
import matplotlib.pyplot as plt

# Others
import time

# %% [markdown]
# ## 2. Read the data

# %%
X1 = torch.load('X1_ready')
Y1 = pd.read_csv("Y1.csv", header=None, names=['revenue '])

# %% [markdown]
# ## 4. Feature Selection

# %% [markdown]
# ### 4.1 Correlation Matrix

# %%
sns.heatmap(pd.concat([pd.DataFrame(X1), Y1], axis=1).corr())
# Out:
# <AxesSubplot:>
