# %%
# Data processing packages
import numpy as np
import pandas as pd
from collections import Counter

# Machine learning packages
from sklearn.model_selection import GridSearchCV, RepeatedKFold, cross_val_score, KFold, train_test_split
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MultiLabelBinarizer, FunctionTransformer
from sklearn.pipeline import Pipeline
from mlxtend.feature_selection import SequentialFeatureSelector
from sklearn.feature_selection import RFE, SelectPercentile, chi2, mutual_info_regression, SelectFromModel
from mlxtend.plotting import plot_sequential_feature_selection as plot_sfs
from sklearn.linear_model import LinearRegression, Lasso
from sklearn.neighbors import KNeighborsRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.decomposition import PCA, KernelPCA, FastICA
from sklearn.manifold import TSNE
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.neural_network import MLPRegressor

import torch
# from keras.models import Sequential
# from keras.layers import Activation, Dense
# from keras import optimizers
# from keras.layers import BatchNormalization

# Visualization packages
import seaborn as sns
import matplotlib.pyplot as plt

# Others
import time
from pathlib import Path

# %% [markdown]
# ## 5. Models

# %%
X1_pca = torch.load('X1_pca').to_numpy()
X1_ica = torch.load('X1_ica').to_numpy()
X1_tsne = torch.load('X1_tsne').to_numpy()
Y1 = pd.read_csv("Y1.csv", header=None, names=['revenue ']).to_numpy().ravel()
X_train_pca, X_test_pca, y_train, y_test = train_test_split(X1_pca, Y1, random_state=42, test_size=0.1)
X_train_ica, X_test_ica, _, _ = train_test_split(X1_ica, Y1, random_state=42, test_size=0.1)
X_train_tsne, X_test_tsne, _, _ = train_test_split(X1_tsne, Y1, random_state=42, test_size=0.1)

# %% [markdown]
# ### 5.3 MLP

# %%
mlp = MLPRegressor(random_state=42, max_iter=1000, verbose=0)
hidden_layer_lists = [
    (200,),
    # (200, 175,),
    (200, 175, 150,),
    # (200, 175, 150, 125,),
    (200, 175, 150, 125, 100,),
    # (200, 175, 150, 125, 100, 75,),
    (200, 175, 150, 125, 100, 75, 50,),
    # (200, 175, 150, 125, 100, 75, 50, 25,),
    (200, 175, 150, 125, 100, 75, 50, 25, 10)
]
mlp_parameter_grid = {
    'hidden_layer_sizes': hidden_layer_lists,
    'activation': ['tanh', 'relu'],
    'solver': ['sgd', 'adam'],
    'alpha': [0.0001, 0.05],
    'batch_size': [177],
    'learning_rate': ['constant','adaptive'],
}

# %%
mlp_grid_pca = GridSearchCV(mlp, mlp_parameter_grid, cv=10, scoring='neg_root_mean_squared_error', return_train_score=True,verbose=2)
mlp_grid_ica = GridSearchCV(mlp, mlp_parameter_grid, cv=10, scoring='neg_root_mean_squared_error', return_train_score=True,verbose=2)
mlp_grid_tsne = GridSearchCV(mlp, mlp_parameter_grid, cv=10, scoring='neg_root_mean_squared_error', return_train_score=True,verbose=2)

# %%
mlp_grid_pca.fit(X_train_pca, np.log(1 + y_train))
# Out:
# Fitting 10 folds for each of 80 candidates, totalling 800 fits
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  29.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  32.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  42.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  39.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  26.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  21.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  23.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  20.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  22.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   8.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   8.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=  10.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   9.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  25.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  23.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  32.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  19.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  21.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  21.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  21.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  17.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  13.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  13.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  16.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  15.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  15.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  11.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   9.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   9.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  23.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  19.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  26.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  19.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  20.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  20.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  19.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  22.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  25.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  25.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   9.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   9.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  19.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  21.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  18.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  27.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  23.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  12.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  12.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  18.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  12.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  12.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   7.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  12.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  25.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  23.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  26.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  22.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  24.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  32.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  28.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  41.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  34.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  24.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  12.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  11.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   7.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  10.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  11.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  12.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  10.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  13.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  13.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  20.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  15.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  14.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  30.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  34.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  38.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  11.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  16.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   2.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   2.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=  18.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   2.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   2.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   3.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   3.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   3.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   2.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   3.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time= 1.1min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time= 1.2min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  30.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  51.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time= 1.1min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  38.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  41.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  38.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time= 1.0min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  40.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   2.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=  17.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   2.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   2.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   3.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  18.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  14.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  31.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  31.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  16.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  34.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  28.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  16.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   1.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   1.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  15.9s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  51.6s
# /Users/maurice/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:696: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (1000) reached and the optimization hasn't converged yet.
#   ConvergenceWarning,
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time= 1.6min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  48.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  37.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time= 1.1min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  41.2s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  35.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  32.5s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  53.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time= 1.6min
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  15.8s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.0s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  17.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.6s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.3s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.4s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  16.1s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  15.7s
# [CV] END activation=tanh, alpha=0.0001, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=  15.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  20.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  18.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  20.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  20.2s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  19.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=sgd; total time=  20.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   7.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=  10.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   8.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   9.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   9.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   9.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   8.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=constant, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  21.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  28.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  19.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=sgd; total time=  20.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   7.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   9.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=  10.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   9.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   9.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200,), learning_rate=adaptive, solver=adam; total time=   8.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  12.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  13.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  12.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  14.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=sgd; total time=  13.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.2s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   9.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=constant, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  20.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  18.2s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  24.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  19.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  19.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  18.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  18.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  21.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  17.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=sgd; total time=  21.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   8.0s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   9.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150), learning_rate=adaptive, solver=adam; total time=   7.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  21.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  17.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  17.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  17.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  18.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  18.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  13.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  12.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  12.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=sgd; total time=  22.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  11.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.9s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   8.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.5s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=   9.2s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=constant, solver=adam; total time=  10.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  28.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  23.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  24.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  22.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  23.8s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  26.4s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  28.6s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  41.1s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  33.2s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  27.7s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   9.3s
# [CV] END activation=tanh, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=  11.5s
# ...
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=sgd; total time=  13.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   6.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100), learning_rate=adaptive, solver=adam; total time=   4.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   8.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=  11.8s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   7.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   7.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   7.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   4.8s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   4.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   6.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   6.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=sgd; total time=   6.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   4.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   4.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   4.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   5.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   4.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   6.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=constant, solver=adam; total time=   4.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  13.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  17.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  13.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  12.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  12.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  11.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  14.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  12.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  12.8s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=sgd; total time=  12.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   4.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   4.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   4.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   6.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   4.6s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   6.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   7.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   6.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50), learning_rate=adaptive, solver=adam; total time=   4.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   8.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=  13.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.8s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   5.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   7.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=sgd; total time=   6.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   7.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   7.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   7.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   5.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=constant, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  12.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  18.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  12.5s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  14.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.3s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=sgd; total time=  13.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   7.1s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   7.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.4s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.2s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   7.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.0s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   5.9s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.7s
# [CV] END activation=relu, alpha=0.05, batch_size=177, hidden_layer_sizes=(200, 175, 150, 125, 100, 75, 50, 25, 10), learning_rate=adaptive, solver=adam; total time=   6.0s
# GridSearchCV(cv=10,
#              estimator=MLPRegressor(max_iter=1000, random_state=42, verbose=0),
#              param_grid={'activation': ['tanh', 'relu'],
#                          'alpha': [0.0001, 0.05], 'batch_size': [177],
#                          'hidden_layer_sizes': [(200,), (200, 175, 150),
#                                                 (200, 175, 150, 125, 100),
#                                                 (200, 175, 150, 125, 100, 75,
#                                                  50),
#                                                 (200, 175, 150, 125, 100, 75,
#                                                  50, 25, 10)],
#                          'learning_rate': ['constant', 'adaptive'],
#                          'solver': ['sgd', 'adam']},
#              return_train_score=True, scoring='neg_root_mean_squared_error',
#              verbose=2)

# %%
torch.save(mlp_grid_pca, "../models/mlp_grid_pca")

# %%
print("The best parameters are:", mlp_grid_pca.best_params_)
print("The best RMSE is:", mlp_grid_pca.best_score_)
# Out:
# The best parameters are: {'activation': 'tanh', 'alpha': 0.0001, 'batch_size': 177, 'hidden_layer_sizes': (200,), 'learning_rate': 'constant', 'solver': 'adam'}
# The best RMSE is: -2.366255956054574

# %%
# y_pred_mlp_pca = np.exp(mlp_grid_pca.predict(X_test_pca)) - 1
# print("Root mean squared error (ICA Embeddings): {:.2f} Millions".format(np.sqrt(mean_squared_error(y_test, y_pred_mlp_pca)) / 1000000))

# %%
mlp_grid_ica.fit(X_train_ica, np.log(1 + y_train))

# %%
torch.save(mlp_grid_ica, "../models/mlp_grid_ica")

# %%
print("The best parameters are:", mlp_grid_ica.best_params_)
print("The best RMSE is:", mlp_grid_ica.best_score_)

# %%
mlp_grid_tsne.fit(X_train_tsne, np.log(1 + y_train))

# %%
torch.save(mlp_grid_tsne, "../models/mlp_grid_tsne")

# %%
print("The best parameters are:", mlp_grid_tsne.best_params_)
print("The best RMSE is:", mlp_grid_tsne.best_score_)
